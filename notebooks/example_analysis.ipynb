# %% [markdown]
# # Gym Review Analysis - Example Notebook
#
# This notebook demonstrates how to use the Gym Review Analysis toolkit to analyze customer reviews and extract actionable insights.

# %%
# Import necessary libraries
import sys
import os
sys.path.append('../src')

from gym_review_analysis import GymReviewAnalyzer
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Initialize the Analyzer

# %%
# Create analyzer instance
analyzer = GymReviewAnalyzer()
print("Analyzer initialized successfully!")
